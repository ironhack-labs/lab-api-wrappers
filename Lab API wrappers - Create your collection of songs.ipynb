# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='68cdc51122f14430a49f7f54a4126938',
                                                           client_secret='3b10490f95c04d97b2064d56788ff8f1'))

results = sp.search(q="artist:guns n' roses", limit=50,offset=N)
N =50
d = []
for idx, track in enumerate(results['tracks']['items']):
    d.append (
        {
            'Track' : track['name'],
            'Album' : track['album']['name'],
            'Artist' : track['artists'][0]['name'],
            'Release Date' : track['album']['release_date'],            
            'Track Number' : track['track_number'],
            'Popularity' : track['popularity'],
            'Track Number' : track['track_number'],
            'Explicit' : track['explicit'],
            'Duration' : track['duration_ms'],
            'Audio Preview URL' : track['preview_url'],
            'Album URL' : track['album']['external_urls']['spotify']
            N =+50
        }
    )

pd.DataFrame(d)
# Out:
#   Cell In[7], line 24
#     'Album URL' : track['album']['external_urls']['spotify']
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(
    client_id = 'ef03f4f0e85e4754aa87c81edff21f2e',
    client_secret = '15cca626491d492d8ec06be346fa492e' ))
sp

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='68cdc51122f14430a49f7f54a4126938',
                                                           client_secret='3b10490f95c04d97b2064d56788ff8f1'))

N = 0  # Initialize offset
d = []

# Assuming you want to get results for multiple pages
for _ in range(5):  # Change 5 to the number of pages you want to fetch
    results = sp.search(q="artist:guns n' roses", limit=50, offset=N)
    
    for idx, track in enumerate(results['tracks']['items']):
        d.append({
            'Track': track['name'],
            'Album': track['album']['name'],
            'Artist': track['artists'][0]['name'],
            'Release Date': track['album']['release_date'],            
            'Track Number': track['track_number'],
            'Popularity': track['popularity'],
            'Explicit': track['explicit'],
            'Duration': track['duration_ms'],
            'Audio Preview URL': track['preview_url'],
            'Album URL': track['album']['external_urls']['spotify']
        })

    N += 50  # Increment offset for the next page

df = pd.DataFrame(d)

# %%
df
# Out:
#                                                  Track  \
# 0                                  Sweet Child O' Mine
# 1                                Welcome To The Jungle
# 2                                        Paradise City
# 3                            Knockin' On Heaven's Door
# 4                                        November Rain
# ..                                                 ...
# 245           Back Off Bitch - 1986 Sound City Session
# 246                               Coma - 2022 Remaster
# 247               The Plague - 1986 Sound City Session
# 248                      Don't Damn Me - 2022 Remaster
# 249  Drum Solo - Live In New York, Ritz Theatre - M...
#
#                                                Album         Artist  \
# 0                           Appetite For Destruction  Guns N' Roses
# 1                           Appetite For Destruction  Guns N' Roses
# 2                           Appetite For Destruction  Guns N' Roses
# ...

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='68cdc51122f14430a49f7f54a4126938',
                                                           client_secret='3b10490f95c04d97b2064d56788ff8f1'))

playlist_id = '6yPiKpy7evrwvZodByKvM9'  # Replace 'your_playlist_id' with the actual playlist ID

N = 0  # Initialize offset
d = []

# Assuming you want to get results for multiple pages
for _ in range(20):  # Change 5 to the number of pages you want to fetch
    results = sp.playlist_items(playlist_id, limit=50, offset=N)
    
    for idx, track in enumerate(results['items']):
        track_info = track['track']
        d.append({
            'Track': track_info['name'],
            'Album': track_info['album']['name'],
            'Artist': track_info['artists'][0]['name'],
            'Release Date': track_info['album']['release_date'],            
            'Track Number': track_info['track_number'],
            'Popularity': track_info['popularity'],
            'Explicit': track_info['explicit'],
            'Duration': track_info['duration_ms'],
            'Audio Preview URL': track_info['preview_url'],
           
        })

    N += 50  # Increment offset for the next page

df = pd.DataFrame(d)

# %%
df
# Out:
#                              Track  \
# 0                               2K
# 1                  4 Billion Souls
# 2                 4 Minute Warning
# 3                        7 Element
# 4                         #9 Dream
# ..                             ...
# 995  Garden of England - Interlude
# 996                       Gasoline
# 997                         Gaston
# 998                     Gatekeeper
# 999   Gathering All the Lost Loves
#
#                                                  Album             Artist  \
# 0    Get Physical Music Presents: Body Language, Vo...        Nosaj Thing
# 1                                          Full Circle          The Doors
# 2                                 In Rainbows (Disk 2)          Radiohead
# 3                                Philosophy of Miracle              Vitas
# 4    Instant Karma: The Amnesty International Campa...             R.E.M.
# ..                                                 ...                ...
# ...
