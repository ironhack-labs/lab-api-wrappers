# %%
#Instructions
#To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!

#These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song 
# from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make 
# sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.

#The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, 
# even hours) to get all the data you need.

#An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the 
# playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
sp=spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="1daa9df0ddca4d54a96bcda5948d24f5",
    client_secret="b9bdfe2740a048de85baacfbd696ae62"))

# %%
playlist = sp.user_playlist_tracks("spotify","spotify:playlist:37i9dQZF1DXc6IFF23C9jj")

# %%
tracks = playlist["items"]
tracks
# Out:
# [{'added_at': '2022-02-17T23:02:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AR',
#      'AU',
#      'BN',
#      'BO',
#      'BZ',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HK',
#      'HN',
#      'ID',
#      'IN',
#      'KH',
#      'KR',
#      'LA',
#      'MO',
#      'MX',
#      'MY',
# ...

# %%
tracks[0]["track"].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
tracks[0]["track"]["id"]
# Out:
# '7BqBn9nzAq8spo5e7cZ0dJ'

# %%
tracks[0]["track"]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
def getSongIds(playlist_id):
    song_ids = []
    playlist = sp.playlist(playlist_id)
    total_songs = playlist['tracks']['total']
    offset = 0
    while len(song_ids) < total_songs:
        playlist_items = sp.playlist_items(playlist_id, offset=offset)['items']
        for item in playlist_items:
            song_id = item['track']['id']
            if song_id not in song_ids:
                song_ids.append(song_id)
        offset += 100
    return song_ids

getSongIds("spotify:playlist:37i9dQZF1DXc6IFF23C9jj")
# Out:
# ['7BqBn9nzAq8spo5e7cZ0dJ',
#  '15JINEqzVMv3SvJTAXAKED',
#  '0SiywuOBRcynK0uKGWdCnn',
#  '2GYHyAoLWpkxLVa4oYTVko',
#  '0HPD5WQqrq7wPWR7P7Dw1i',
#  '4dTaAiV9xFFCxnPur9c9yL',
#  '2CEgGE6aESpnmtfiZwYlbV',
#  '2ENexcMEMsYk0rVJigVD3i',
#  '6tS3XVuOyu10897O3ae7bi',
#  '4HlFJV71xXKIGcU3kRyttv',
#  '6epn3r7S14KUqlReYr77hA',
#  '161DnLWsx1i3u1JT05lzqU',
#  '7Ie9W94M7OjPoZVV216Xus',
#  '2a1o6ZejUi8U3wzzOtCOYw',
#  '4356Typ82hUiFAynbLYbPn',
#  '60jzFy6Nn4M0iD1d94oteF',
#  '6cmm1LMvZdB5zsCwX5BjqE',
#  '3DamFFqW32WihKkTVlwTYQ',
#  '6ebkx7Q5tTxrCxKq4GYj0Y',
#  '7ElF5zxOwYP4qVSWVvse3W',
#  '2V4bv1fNWfTcyRJKmej6Sj',
#  '3ZdJffjzJWFimSQyxgGIxN',
#  '6lV2MSQmRIkycDScNtrBXO',
#  '1bM50INir8voAkVoKuvEUI',
#  '4TCL0qqKyqsMZml0G3M9IM',
#  '5jzKL4BDMClWqRguW5qZvh',
#  '6DkXLzBQT7cwXmTyzAB1DJ',
#  '3GBApU0NuzH4hKZq4NOSdA',
#  '2M9ULmQwTaTGmAdXaXpfz5',
#  '5vlEg2fT4cFWAqU5QptIpQ',
#  '4AYX69oFP3UOS1CFmV9UfO',
#  '59dLtGBS26x7kc0rHbaPrq',
#  '1HHeOs6zRdF8Ck58easiAY',
#  '5sra5UY6sD658OabHL3QtI',
# ...

# %%
songs_ids=getSongIds("spotify:playlist:37i9dQZF1DXc6IFF23C9jj")
songs_ids
# Out:
# ['7BqBn9nzAq8spo5e7cZ0dJ',
#  '15JINEqzVMv3SvJTAXAKED',
#  '0SiywuOBRcynK0uKGWdCnn',
#  '2GYHyAoLWpkxLVa4oYTVko',
#  '0HPD5WQqrq7wPWR7P7Dw1i',
#  '4dTaAiV9xFFCxnPur9c9yL',
#  '2CEgGE6aESpnmtfiZwYlbV',
#  '2ENexcMEMsYk0rVJigVD3i',
#  '6tS3XVuOyu10897O3ae7bi',
#  '4HlFJV71xXKIGcU3kRyttv',
#  '6epn3r7S14KUqlReYr77hA',
#  '161DnLWsx1i3u1JT05lzqU',
#  '7Ie9W94M7OjPoZVV216Xus',
#  '2a1o6ZejUi8U3wzzOtCOYw',
#  '4356Typ82hUiFAynbLYbPn',
#  '60jzFy6Nn4M0iD1d94oteF',
#  '6cmm1LMvZdB5zsCwX5BjqE',
#  '3DamFFqW32WihKkTVlwTYQ',
#  '6ebkx7Q5tTxrCxKq4GYj0Y',
#  '7ElF5zxOwYP4qVSWVvse3W',
#  '2V4bv1fNWfTcyRJKmej6Sj',
#  '3ZdJffjzJWFimSQyxgGIxN',
#  '6lV2MSQmRIkycDScNtrBXO',
#  '1bM50INir8voAkVoKuvEUI',
#  '4TCL0qqKyqsMZml0G3M9IM',
#  '5jzKL4BDMClWqRguW5qZvh',
#  '6DkXLzBQT7cwXmTyzAB1DJ',
#  '3GBApU0NuzH4hKZq4NOSdA',
#  '2M9ULmQwTaTGmAdXaXpfz5',
#  '5vlEg2fT4cFWAqU5QptIpQ',
#  '4AYX69oFP3UOS1CFmV9UfO',
#  '59dLtGBS26x7kc0rHbaPrq',
#  '1HHeOs6zRdF8Ck58easiAY',
#  '5sra5UY6sD658OabHL3QtI',
# ...

# %%
def getArtistIds(playlist_id):
    artists_ids = []    
    for song_id in songs_ids:
        song_info = sp.track(song_id)

        for artist in song_info['artists']:
            if artist['id'] not in artists_ids:
                artists_ids.append(artist['id'])
    return artists_ids
                
artists_ids=getArtistIds("spotify:playlist:37i9dQZF1DXc6IFF23C9jj")
artists_ids
# Out:
# ['0du5cEVh5yTK9QJze8zA0C',
#  '7dGJo4pcD2V6oG8kP0tJRR',
#  '5pKCCKE2ajJHZ9KAiaK11H',
#  '1HY2Jd0NmPuamShAr6KMms',
#  '5j4HeCoUlzhfWtjAfM1acR',
#  '6LqNN22kT3074XbTVUrhzX',
#  '1Cs0zKBU1kc0i8ypK3B9ai',
#  '0fA0VVWsXO9YnASrzqfmYu',
#  '6MF9fzBmfXghAz953czmBC',
#  '6jJ0s89eD6GaHleKKya26X',
#  '7hJcb9fa4alzcOq3EaNPoG',
#  '3FUY2gzHeIiaesXtOAdB7A',
#  '1uNFoZAHBGtllmzznpCI3s',
#  '3ipn9JLAPI5GUEo4y4jcoi',
#  '33ScadVnbm2X8kkUqOkC6Z',
#  '5bv5RplEOwdCvhq0EILh9E',
#  '23zg3TcAtWQy7J6upgbUnj',
#  '0TnOYISbd1XYRBk9myaseg',
#  '4pADjHPWyrlAF0FA7joK2H',
#  '55Aa2cqylxrFIXC767Z865',
#  '07QEuhtrNmmZ0zEcqE9SF6',
#  '0jnsk9HBra6NMjO2oANoPY',
#  '2KsP6tYLJlTBvSUxnwlVWa',
#  '1Bo8Afb2Qbjs4x6kJHyjle',
#  '2gBjLmx6zQnFGQJCAQpRgw',
#  '5ndkK3dpZLKtBklKjxNQwT',
#  '6Rx1JKzBrSzoKQtmbVmBnM',
#  '085pc2PYOi8bGKj0PNjekA',
#  '6vWDO969PvNqNYHIOW5v0m',
#  '3TVXtAsR1Inumwj472S9r4',
#  '536BYVgOnRky0xjsPT96zl',
#  '7o9Nl7K1Al6NNAHX6jn6iG',
#  '5tKXB9uuebKE34yowVaU3C',
#  '2iojnBLj0qIMiKPvVhLnsH',
# ...

# %%
def getAlbumIds(artist_ids):
    album_ids = []
    for artist_id in artist_ids:
        albums = sp.artist_albums(artist_id, album_type='album')
        for album in albums['items']:
            if album['id'] not in album_ids:
                album_ids.append(album['id'])
    return album_ids
                
album_ids=getAlbumIds(artists_ids)
album_ids
# Out:
# ['4VZ7jhV0wHpoNPCB7Vmiml',
#  '1YgekJJTEueWDaMr7BYqPk',
#  '4PgleR09JVnm3zY1fW3XBA',
#  '4w6KUt7eyD4paTTNctylCS',
#  '7KBjLhk3IM27k3ry4vBk3i',
#  '58ufpQsJ1DS5kq4hhzQDiI',
#  '4xWulj18AGahlyuZPulaGe',
#  '6J84szYCnMfzEcvIcfWMFL',
#  '1uyf3l2d4XYwiEqAb7t7fX',
#  '3aTuW4BtsyyyyQa9LKqj8n',
#  '6GwBcopd79zidRXsN4MSg4',
#  '6EzbFdrwvWpnpUjzrR57aU',
#  '3MKvhQoFSrR2PrxXXBHe9B',
#  '7JhGOo4ojHVgNbFdxHGUgD',
#  '4otkd9As6YaxxEkIjXPiZ6',
#  '2LWLgGY15e9im0KUaASnFa',
#  '3HNnxK7NgLXbDoxRZxNWiR',
#  '5pJBqddqlkBbGKQvljZIms',
#  '7lYuRLWepcofczV4XIdoxJ',
#  '0U6ldwLBEMkwgfQRY4V6D2',
#  '7cwcyW39NGUAiukHc1MOFD',
#  '2mzSjECCtpaHI9GEt5lbkP',
#  '02BQFiWcFYKb5iJIKVpPap',
#  '6DN7GcZF1HywzrkGN6Eeqk',
#  '3vOgbDjgsZBAPwV2M3bNOj',
#  '6Vn28iXHIwxmvh4Va0hSoe',
#  '2NDWe8wEVGozh9VigPwQGj',
#  '1UiPHgFputxSUssPibAVxc',
#  '1YVirtsO6xC4eTfJnUL3yK',
#  '06RK0wX4GqHcxBtHlVoGH5',
#  '4UlGauD7ROb3YbVOFMgW5u',
#  '4Q3ad90GtI0dxyE5ZishAS',
#  '48i37aZTC1prDr4EcpQeEa',
#  '3p39yDJtXkSw8QLMmB8yyD',
# ...

# %%
len(album_ids)
# Out:
# 1386

# %%
def getAllSongs(album_ids):
    song_ids = []
    for album_id in album_ids:
        tracks = sp.album_tracks(album_id)
        for track in tracks['items']:
            if track['id'] not in song_ids:
                song_ids.append(track['id'])
    return song_ids

allsongs_ids=getAllSongs(album_ids)
allsongs_ids
# Out:
# ['4K09vJ27xCOreumtSuU6Ao',
#  '4pryE6cN2gFL1FVF5fYINl',
#  '7suB6D6uKX5DfPukdGaz0W',
#  '6jGAh1bFnXt1Muj9zeHveZ',
#  '1oERlssLrpssCAY6Yqqs6c',
#  '5lka5RUbLVQGO94mKAPMRO',
#  '2K6vUau7bnZUamjbRSOOvJ',
#  '3WTWh2WDk4j8GUCGj4xfOd',
#  '2ALh2jqA7KldpHMUHvRomw',
#  '2NqyjfDXy0XfXCSPXMsKzi',
#  '7LK0IWXe2Yd0JGgSjJThex',
#  '02VBYrHfVwfEWXk5DXyf0T',
#  '3a6FcTyvSf0ED3VXeH3PJ5',
#  '3jiKUMXqwEodB7gVv1RMZU',
#  '3xVZYkcuWalGudeKl861wb',
#  '5f7UJCMrA1VRLvbPrq1h0G',
#  '67BOjO8BESXYNU5E6qDcUv',
#  '7jvCeWOSnJs2N3spqobWnO',
#  '2JUQ7mV1AHk2owXLydmN4Z',
#  '2kpoReN3MY7I0tSF902n0z',
#  '6b8Be6ljOzmkOmFslEb23P',
#  '0mBKv9DkYfQHjdMcw2jdyI',
#  '1I6pKIyaBp4OebTGLJpCCC',
#  '0KKkJNfGyhkQ5aFogxQAPU',
#  '0kN8xEmgMW9mh7UmDYHlJP',
#  '2mrZYZGmPFV3QOyYPZ1zsn',
#  '6ObpR8ek44tvWefQRcSo8K',
#  '5XMkENs3GfeRza8MfVAhjK',
#  '0B0tYbVp7pDQAqKDhgMeaL',
#  '5Pr2AFUNbDMo73grOJDWvy',
#  '2VoO0foG09SUeuat3wYLNG',
#  '13dX0sTiBQabys1vYMjmIk',
#  '5rCuwVqnDRL45hxb7cm6SJ',
#  '6dvacupcEKreloCB9nkAsT',
# ...

# %%
len(allsongs_ids)
# Out:
# 21775
