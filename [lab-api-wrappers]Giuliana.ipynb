# %%
import requests
import pandas as pd

# import specific wrapper libs

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(
client_id = 'a1f5519a6c8941a788ef33c5bac1a2b8', client_secret = 'ed32cb25de504e178e2ae524f57a20d4'
))

# %%
playlist = sp.user_playlist_tracks('spotify', '4mroWzORnXk9lOxXM8x02b')
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4mroWzORnXk9lOxXM8x02b/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-03-27T15:40:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/11158014711'},
#     'href': 'https://api.spotify.com/v1/users/11158014711',
#     'id': '11158014711',
#     'type': 'user',
#     'uri': 'spotify:user:11158014711'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ'},
#        'href': 'https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ',
#        'id': '7HGNYPmbDrMkylWqeFCOIQ',
#        'name': 'Caetano Veloso',
#        'type': 'artist',
#        'uri': 'spotify:artist:7HGNYPmbDrMkylWqeFCOIQ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/57IX1XTNL4DPilyY5pQsaK'},
# ...

# %%
playlist['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
track_name = []
track_artists = []
track_album = []
track_duration = []
track_expli = []
track_href = []
track_pop = []

for item in playlist['items']:
    track_name.append(item['track']['name'])
    track_album.append(item['track']['album']['name'])
    
    # Adicione lógica para 'artists', 'duration_ms', 'explicit', 'href', e 'popularity'
    track_artists.append(', '.join([artist['name'] for artist in item['track']['artists']]))
    track_duration.append(item['track']['duration_ms'])
    track_expli.append(item['track']['explicit'])
    track_href.append(item['track']['href'])
    track_pop.append(item['track']['popularity'])

playlist_df = pd.DataFrame({
    'Track Name': track_name,
    'Artists': track_artists,
    'Album': track_album,
    'Duration (ms)': track_duration,
    'Explicit': track_expli,
    'Href': track_href,
    'Popularity': track_pop,
})

playlist_df
# Out:
#                                Track Name                        Artists  \
# 0                 Deusa Do Amor - Ao Vivo  Caetano Veloso, Moreno Veloso
# 1                    O Quereres - Ao Vivo        Caetano Veloso, Mazzola
# 2   Voce E Linda - Remixed Original Album                 Caetano Veloso
# 3       Quem Te Viu, Quem Te Vê - Ao Vivo                  Chico Buarque
# 4                               Ainda Bem                   Marisa Monte
# ..                                    ...                            ...
# 58                          Mosca Na Sopa                    Raul Seixas
# 59            Nada Sei (Apnéia) - Ao Vivo                     Kid Abelha
# 60                              Não Enche                 Caetano Veloso
# 61            Eu Preciso Dizer Que Te Amo                 Bebel Gilberto
# 62              Oração Ao Tempo - Ao Vivo                 Caetano Veloso
#
#                                                 Album  Duration (ms)  \
# ...

# %%
track_name = []
track_artists = []
track_album = []
track_duration = []
track_expli = []
track_href = []
track_pop = []

for item in playlist['items']:
    track_name.append(item['track']['name'])
    track_album.append(item['track']['album']['name'])
    
    # Adicione lógica para 'artists', 'duration_ms', 'explicit', 'href', e 'popularity'
    track_artists.append(', '.join([artist['name'] for artist in item['track']['artists']]))
    track_duration.append(item['track']['duration_ms'])
    track_expli.append(item['track']['explicit'])
    track_href.append(item['track']['href'])
    track_pop.append(item['track']['popularity'])

playlist_df = pd.DataFrame({
    'Track Name': track_name,
    'Artists': track_artists,
    'Album': track_album,
    'Duration (ms)': track_duration,
    'Explicit': track_expli,
    'Href': track_href,
    'Popularity': track_pop,
})

# %%
# a very big playlist 

track_name = []
track_artists = []
track_album = []
track_duration = []
track_expli = []
track_href = []
track_pop = []

for count in range(0, 10000,100):
    playlist = sp.user_playlist_tracks(user="spotify",
                                       playlist_id="6yPiKpy7evrwvZodByKvM9",
                                       limit=100,
                                       offset=count)
    
    for item in playlist['items']:
        track_name.append(item['track']['name'])
        track_album.append(item['track']['album']['name'])
        
        track_artists.append(', '.join([artist['name'] for artist in item['track']['artists']]))
        track_duration.append(item['track']['duration_ms'])
        track_expli.append(item['track']['explicit'])
        track_href.append(item['track']['href'])
        track_pop.append(item['track']['popularity'])


df_1 = pd.DataFrame({
    'Track Name': track_name,
    'Artists': track_artists,
    'Album': track_album,
    'Duration (ms)': track_duration,
    'Explicit': track_expli,
    'Href': track_href,
    'Popularity': track_pop,
})
# Out:
#                        Track Name         Artists  \
# 0                              2K     Nosaj Thing
# 1                 4 Billion Souls       The Doors
# 2                4 Minute Warning       Radiohead
# 3                       7 Element           Vitas
# 4                        #9 Dream          R.E.M.
# ...                           ...             ...
# 9995  London Calling - Remastered       The Clash
# 9996                    Low Rider             War
# 9997                       Flower            Moby
# 9998           Brighter Than Gold  The Cat Empire
# 9999     Fury of the Storm - Live     DragonForce
#
#                                                   Album  Duration (ms)  \
# 0     Get Physical Music Presents: Body Language, Vo...         152560
# 1                                           Full Circle         197706
# 2                                  In Rainbows (Disk 2)         244284
# 3                                 Philosophy of Miracle         249939
# ...

# %%
df_1
# Out:
#                        Track Name         Artists  \
# 0                              2K     Nosaj Thing
# 1                 4 Billion Souls       The Doors
# 2                4 Minute Warning       Radiohead
# 3                       7 Element           Vitas
# 4                        #9 Dream          R.E.M.
# ...                           ...             ...
# 9995  London Calling - Remastered       The Clash
# 9996                    Low Rider             War
# 9997                       Flower            Moby
# 9998           Brighter Than Gold  The Cat Empire
# 9999     Fury of the Storm - Live     DragonForce
#
#                                                   Album  Duration (ms)  \
# 0     Get Physical Music Presents: Body Language, Vo...         152560
# 1                                           Full Circle         197706
# 2                                  In Rainbows (Disk 2)         244284
# 3                                 Philosophy of Miracle         249939
# ...

# %%
track_name = []
track_artists = []
track_album = []
track_duration = []
track_expli = []
track_href = []
track_pop = []


for count in range(0, 1000, 50):
    anitta = sp.search(q = 'anitta', limit=50,
                                       offset=count)
    
    for i in anitta['tracks']['items']:
        track_name.append(i['name'])
        track_album.append(i['album']['name'])
        track_duration.append(i['duration_ms'])
        track_expli.append(i['explicit'])
        track_href.append(i['href'])
        track_pop.append(i['popularity'])
    
    
        # concatenating the artists
        artists_list = i['artists']
        concatenated_artists = ', '.join([artist['name'] for artist in artists_list])
        track_artists.append(concatenated_artists)

    

# Imprimir o comprimento de cada lista
print(f"Length of Track Name: {len(track_name)}")
print(f"Length of Artists: {len(track_artists)}")
print(f"Length of Album: {len(track_album)}")
print(f"Length of Duration: {len(track_duration)}")
print(f"Length of Explicit: {len(track_expli)}")
print(f"Length of Href: {len(track_href)}")
print(f"Length of Popularity: {len(track_pop)}")
# Out:
# Length of Track Name: 1000
# Length of Artists: 1000
# Length of Album: 1000
# Length of Duration: 1000
# Length of Explicit: 1000
# Length of Href: 1000
# Length of Popularity: 1000

# %%
anitta_df = pd.DataFrame({
    'Track Name': track_name,
    'Artists': track_artists,
    'Album': track_album,
    'Duration (ms)': track_duration,
    'Explicit': track_expli,
    'Href': track_href,
    'Popularity': track_pop,
})

# %%
anitta_df
# Out:
#                       Track Name                      Artists  \
# 0                       BELLAKEO           Peso Pluma, Anitta
# 1                       Envolver                       Anitta
# 2                       Envolver                       Anitta
# 3    Back for More (with Anitta)  TOMORROW X TOGETHER, Anitta
# 4                       Downtown             Anitta, J Balvin
# ..                           ...                          ...
# 995                El que espera               Anitta, Maluma
# 996                    Até o céu         Anitta, MC Cabelinho
# 997                  Vai e volta                       Anitta
# 998                     Ai papai   Anitta, Mc Danny, HITMAKER
# 999                     Envolver                       Anitta
#
#                               Album  Duration (ms)  Explicit  \
# 0                          BELLAKEO         197333      True
# 1                    Versions of Me         193805     False
# ...

# %%
# Ludmilla

track_name = []
track_artists = []
track_album = []
track_duration = []
track_expli = []
track_href = []
track_pop = []


for count in range(0, 1000, 50):
    ludmilla = sp.search(q = 'ludmilla', limit=50,
                                       offset=count)
    
    for i in ludmilla['tracks']['items']:
        track_name.append(i['name'])
        track_album.append(i['album']['name'])
        track_duration.append(i['duration_ms'])
        track_expli.append(i['explicit'])
        track_href.append(i['href'])
        track_pop.append(i['popularity'])
    
    
        # concatenating the artists
        artists_list = i['artists']
        concatenated_artists = ', '.join([artist['name'] for artist in artists_list])
        track_artists.append(concatenated_artists)

# %%
ludmilla_df = pd.DataFrame({
    'Track Name': track_name,
    'Artists': track_artists,
    'Album': track_album,
    'Duration (ms)': track_duration,
    'Explicit': track_expli,
    'Href': track_href,
    'Popularity': track_pop,
})

# %%
ludmilla_df
# Out:
#                                             Track Name  \
# 0                                              Cheguei
# 1                                          Din din din
# 2                                    Insônia - Ao Vivo
# 3    Medley Lud Session - Modo Avião / A Tua Voz / ...
# 4                                             Invocada
# ..                                                 ...
# 995                                    Garota nota 100
# 996                                   CAFÉ DA MANHÃ ;P
# 997                                           Ludimila
# 998                              Teu Segredo - Ao Vivo
# 999                                        Diz Pra Mim
#
#                              Artists  \
# 0                           LUDMILLA
# 1    LUDMILLA, Mc Doguinha, MC Pupio
# 2         LUDMILLA, Marília Mendonça
# 3            LUDMILLA, Gloria Groove
# 4              LUDMILLA, Leo Santana
# ..                               ...
# ...

# %%
# Pop songs

track_name = []
track_artists = []
track_album = []
track_duration = []
track_expli = []
track_href = []
track_pop = []

for count in range(0, 100,50):
    playlist = sp.user_playlist_tracks(user="spotify",
                                       playlist_id="37i9dQZF1DWVLcZxJO5zyf",
                                       limit=50,
                                       offset=count)
    
    for item in playlist['items']:
        track_name.append(item['track']['name'])
        track_album.append(item['track']['album']['name'])
        
        track_artists.append(', '.join([artist['name'] for artist in item['track']['artists']]))
        track_duration.append(item['track']['duration_ms'])
        track_expli.append(item['track']['explicit'])
        track_href.append(item['track']['href'])
        track_pop.append(item['track']['popularity'])


df_2 = pd.DataFrame({
    'Track Name': track_name,
    'Artists': track_artists,
    'Album': track_album,
    'Duration (ms)': track_duration,
    'Explicit': track_expli,
    'Href': track_href,
    'Popularity': track_pop,
})



df_2
# Out:
#                                            Track Name  \
# 0                                          real valor
# 1                                        Dano Sarrada
# 2                                              POCPOC
# 3                                             Fiu Fiu
# 4                                     SAUDADE DE VOCÊ
# 5                                            Monstrão
# 6                                   Sou Musa do Verão
# 7                                           PREPARADA
# 8                                           BANDIDONA
# 9                                 Alinhamento Milenar
# 10                                 Sexo, poder e arte
# 11                                          Mil Veces
# 12                                           DA BRABA
# 13  Ombrim (ai que delicia o verão) (feat. Mts No ...
# 14                                          La Muerte
# 15                                 Sintomas de Prazer
# ...
